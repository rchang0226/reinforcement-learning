# %%
# %matplotlib inline

import gymnasium as gym
import numpy as np
from matplotlib import pyplot as plt
# Out:
# /home/raymond/anaconda3/envs/tf/lib/python3.8/site-packages/gymnasium/envs/registration.py:521: UserWarning: WARN: Overriding environment GymV26Environment-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/raymond/anaconda3/envs/tf/lib/python3.8/site-packages/gymnasium/envs/registration.py:521: UserWarning: WARN: Overriding environment GymV22Environment-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
env = gym.make("ALE/Breakout-v5", render_mode="rgb_array")

# %%
print("Action space size: {}".format(env.action_space.n))
print(env.get_action_meanings()) # env.unwrapped.get_action_meanings() for gym 0.8.0 or later

observation = env.reset()
print("Observation space shape: {}".format(observation[0].shape))

plt.figure()
plt.imshow(env.render())

[env.step(2) for x in range(1)]
plt.figure()
plt.imshow(env.render())
# Out:
# Action space size: 4
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT']
# Observation space shape: (210, 160, 3)

# %%
# Check out what a cropped image looks like
plt.imshow(observation[0][34:-16,:,:])
